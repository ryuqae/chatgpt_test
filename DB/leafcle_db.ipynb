# %%
from IPython.display import Image
import datetime
import pprint
import getpass

# %%
password = getpass.getpass("Password:")
# Out:
# Password: ········

# %%
import pymongo

client = pymongo.MongoClient("mongodb+srv://snuleafcle:"+password+"@leafcledb-cluster.y4r3ddj.mongodb.net/?retryWrites=true&w=majority")

# # URI access
# mongodb_URI = "mongodb://localhost:27017/"
# client = MongoClient(mongodb_URI)

# %%
Image('user_collection_image.png', width = 600, height = 300)

# %%
Image('ticket_collection_image.png', width = 600, height = 300)

# %%
Image('comment_collection_image.png', width = 600, height = 300)

# %%
Image('user_ticket_collection_image.png', width = 600, height = 300)

# %%
# document - db
leafcle_db = client['leafcle_db']

# collection
user_collection = leafcle_db['user_collection']
ticket_collection = leafcle_db['ticket_collection']
comment_collection = leafcle_db['comment_collection']
user_ticket_collection = leafcle_db['user_ticket_collection']

# %%
# 샘플 유저 데이터
dummy_user = {
     'user_id': 'user_0',
     'last_login_timestamp':
         datetime.datetime(2023, 2, 18, 12, 14, 32, 41239),
     'last_login_location': 
         {"latitude":37.7749, 
          "longitude":-122.4194},
     'last_create_ticket_timestamp': 
         datetime.datetime(2023, 2, 18, 13, 12, 22, 82539),
     'last_create_comment_timestamp':
         datetime.datetime(2023, 2, 18, 13, 32, 16, 25899),
     'user_ticket_count': 22,
     'user_comment_count': 38,
     'user_like_count': 12,
     'user_get_ticket_report_count': 5,
     'user_get_comment_report_count': 32,
     'user_give_ticket_report_count': 7,
     'user_give_comment_report_count': 3
    }

# %%
# 샘플 티켓 데이터
dummy_ticket = {
     'tieckt_id': 'ticket_0',
     'ticket_order': '0',
     'user_id': 'user_0',
     'ticket_created_location': 
         {"latitude":37.7749, 
          "longitude":-122.4194},
     'ticket_created_timestamp': 
         datetime.datetime(2023, 3, 12, 16, 42, 35, 91139),
     'is_ticket_ai_generated': False,
     'is_ticket_admin_generated': False,
     'ticket_content': 
         '요즘 회사일이 너무 힘들어. 매일매일 일이 쌓여가는데, 이렇게 일하다 보면 정신적으로 지쳐버릴 것 같아. 그냥 쉬고 싶어.',
     'ticket_comment_count': 3,
     'ticket_like_count': 2,
     'ticket_report_count': 1,
     'is_ticket_banned': False
    }

# %%
# 샘플 댓글 데이터
dummy_comment = [
    {
     'comment_id': 'comment_0',
     'ticket_id': 'ticket_0',
     'user_id': 'user_0',
     'comment_order': 0,
     'is_comment_ai_generated': False,
     'is_comment_admin_generated': False,
     'comment_created_timestamp': 
         datetime.datetime(2023, 3, 12, 19, 42, 25, 31149),
     'comment_content': 
         '조금씩 일을 나눠서 해보는 건 어때요? 더 이상 혼자서 일을 처리하지 말고 동료들과 나눠보세요.',
     'comment_report_count': 0,
     'is_comment_banned': False
    },
    {
     'comment_id': 'comment_1',
     'ticket_id': 'ticket_0',
     'user_id': 'user_0',
     'comment_order': 1,
     'is_comment_ai_generated': False,
     'is_comment_admin_generated': False,
     'comment_created_timestamp': 
         datetime.datetime(2023, 3, 12, 19, 43, 23, 31149),
     'comment_content': 
         '정말 힘들겠죠. 이런 때에는 쉬는 것도 중요해요. 하루쯤은 푹 쉬어보는 건 어떨까요?',
     'comment_report_count': 0,
     'is_comment_banned': False
    },
    {
     'comment_id': 'comment_2',
     'ticket_id': 'ticket_0',
     'user_id': 'user_0',
     'comment_order': 2,
     'is_comment_ai_generated': False,
     'is_comment_admin_generated': False,
     'comment_created_timestamp': 
         datetime.datetime(2023, 3, 12, 20, 32, 15, 31149),
     'comment_content': 
         '저도 이전에 비슷한 경험이 있었는데, 조금씩 할 일을 나눠서 하니까 훨씬 효율적으로 일이 처리되더라구요. 힘내세요!',
     'comment_report_count': 0,
     'is_comment_banned': False
    }
]

# %%
# 샘플 유저-티켓 데이터
dummy_user_ticket = {
     'user_id': 'user_0',
     'ticket_id': 'tieckt_0',
     'is_user_created': True,
     'is_user_comment': False,
     'is_user_like': False,
     'is_user_report': False,
    }

# %%
# user_collection.drop()
# ticket_collection.drop()
# comment_collection.drop()
# user_ticket_collection.drop()

# %%
# user_collection.insert_one(dummy_user).inserted_id
# ticket_collection.insert_one(dummy_ticket).inserted_id
# user_ticket_collection.insert_one(dummy_user_ticket).inserted_id

# for i in dummy_comment:
    
#     comment_collection.insert_one(i).inserted_id

# %%
for i in user_collection.find():
    pprint.pprint(i)
# Out:
# {'_id': ObjectId('642100c84f01020143164f14'),
#  'last_create_comment_timestamp': datetime.datetime(2023, 2, 18, 13, 32, 16, 25000),
#  'last_create_ticket_timestamp': datetime.datetime(2023, 2, 18, 13, 12, 22, 82000),
#  'last_login_location': {'latitude': 37.7749, 'longitude': -122.4194},
#  'last_login_timestamp': datetime.datetime(2023, 2, 18, 12, 14, 32, 41000),
#  'user_comment_count': 38,
#  'user_get_comment_report_count': 32,
#  'user_get_ticket_report_count': 5,
#  'user_give_comment_report_count': 3,
#  'user_give_ticket_report_count': 7,
#  'user_id': 'user_0',
#  'user_like_count': 12,
#  'user_ticket_count': 22}

# %%
rhim8668
